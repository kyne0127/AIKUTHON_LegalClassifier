판결 【성폭력범죄의처벌및피해자보호등에관한법률위반(13세미만미성년자강간등)등】
# 부산지방법원 2006. 4. 28. 선고 2006고합86 판결 【성폭력범죄의처벌및피해자보호등에관한법률위반(친족관계에의한강간등)】
# 수원지방법원 2006. 5. 3. 선고 2006고합50 판결 【성폭력범죄의처벌및피해자보호등에관한법률위반(강간등상해)·성폭력범죄의처벌및피해자보호등에관한법률...】
# 서울서부지방법원 2006. 6. 29. 선고 2006고합112 판결 【가. 성폭력범죄의처벌및피해자보호등에관한법률위반(특수강도강간등) 등】
# 서울서부지방법원 2006. 7. 27. 선고 2006고합104 판결 【가. 성폭력범죄의처벌및피해자보호등에관한법률위반(강간등치상) 등】
# 부산지법 2008. 4. 25. 선고 2007고합705 판결 : 항소 【미성년자간음】

# %% [markdown]
# # 2.Question Answering format으로 변경

# %%
wb=xlrd.open_workbook("../data/law.xlsx")
# wb=xlrd.open_workbook("./data/law_raw_data_oneanswer.xlsx")

ws=wb.sheet_by_index(0)

# %%
nrow = ws.nrows
ncol = ws.ncols
print("row개수 :",nrow)
print("col개수 :",ncol)
# Out:
# row개수 : 1003
# col개수 : 11

# %%
questionList= [ws.cell_value(0,i) for i in range(ncol)]

qNum = {}

for i in range(len(questionList)) :
    if "?" in questionList[i] :
        qNum[i] = 0


print(questionList)
print(qNum)
# Out:
# ['제목', '개수', '범죄사실', '피해자가 누구인가요?', '피해자_ans', '범행이 언제 발생했나요?', '언제_ans', '범행이 어디서 발생했나요?', '어디서_ans', '어떤 범행이 발생했나요?', '어떤범행_ans']
# {3: 0, 5: 0, 7: 0, 9: 0}

# %%
lawdict = {}

dataList = []
datatmp = {}

paragraphList = []
paragraphtmp = {}

qasList = []
qastmp = {}

ansList = []
anstmp = {}

id = 0



questionList= [ws.cell_value(0,i) for i in range(ncol)]
qNum = {}

for i in range(len(questionList)) :
    if "?" in questionList[i] :
        qNum[i] = 0

print(questionList)
print(qNum)

dataNum = 0

article = []
answer = []

for row in range(2,nrow) :
        
    
    article.append(len(ws.cell_value(row,2)))
    
    for col in range(3,ncol,2) : 
        if len(ws.cell_value(row,col)) > 0 :
            qNum[col] += 1
            
            text = ws.cell_value(row,col)
            startNum = ws.cell_value(row,col+1)
            
            
            anstmp['answer_start'] = startNum
            anstmp['text'] = text
            ansList.append(anstmp)
            anstmp = {}
            
            answer.append(len(text))
    
            qastmp['question'] = questionList[col]
            qastmp['answers'] = ansList
            qastmp['id'] = str(id) 
            
            qasList.append(qastmp)

            ansList = []
            qastmp = {}
            id = id+1
    
    paragraphtmp['context'] = ws.cell_value(row,2).strip()
    paragraphtmp['qas'] = qasList
    
    paragraphList.append(paragraphtmp)
    qasList = []
    paragraphtmp = {}
    
    
    datatmp['title'] = ws.cell_value(row,0).strip()
    
    datatmp['paragraphs'] = paragraphList
#     print(datatmp)
    dataList.append(copy.deepcopy(datatmp))
#     dataList.append(datatmp)
    # copy.deepcopy 안해주면 모두 마지막 값이 들어가있다. 즉 datatmp 값이 모두 같아지는듯..
    # 근데 왜 여기서만 ??
    
    dattmp = {}
    paragraphList = []
    
    dataNum += 1

        
print("데이터 개수 :",dataNum)

random.shuffle(dataList)

lawdict['data'] = dataList
print(qNum)

with open("../data/law.json" , "w", encoding="utf-8") as make_file :
    json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")
# Out:
# ['제목', '개수', '범죄사실', '피해자가 누구인가요?', '피해자_ans', '범행이 언제 발생했나요?', '언제_ans', '범행이 어디서 발생했나요?', '어디서_ans', '어떤 범행이 발생했나요?', '어떤범행_ans']
# {3: 0, 5: 0, 7: 0, 9: 0}
# 데이터 개수 : 1001
# {3: 1001, 5: 1001, 7: 1001, 9: 1001}

# %%
import collections

article = np.array(article)
answer = np.array(answer)

print("지문 평균 글자 수 : " , np.mean(article) , "최수 글자 :" , np.min(article) , "최대 글자 :", np.max(article))

sq = lambda x : int(x/100)
vfunc =  np.vectorize(sq)

article = vfunc(article)

print("백 단위 글자개수 지문 " , collections.Counter(article))

print("답 평균 글자 수 : ", np.mean(answer))
# Out:
# 지문 평균 글자 수 :  345.36842105263156 최수 글자 : 137 최대 글자 : 625
# 백 단위 글자개수 지문  Counter({2: 5, 1: 4, 5: 3, 4: 3, 3: 3, 6: 1})
# 답 평균 글자 수 :  13.276315789473685

# %%
with open("../data/law.json" , "w", encoding="utf-8") as make_file :
    json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")

# %%
lawdict['data']
# Out:
# [{'paragraphs': [{'context': '위 강력5팀 경찰관들은 2010. 3. 31. 11:50경 서울 동대문구 장안동 399의 34 피해자 공소외 23(31세)의 집에서 피해자를 특수절도 등 혐의로 체포하여 피의자로 조사하게 되었다. 피고인 1은 같은 날 13:30경 서울양천경찰서 강력5팀 사무실에서, 피해자가 체포되어 사무실에 들어가자 사무실 안쪽 소파로 앉게 한 다음 한 손으로 피해자의 머리를 잡고, 한 손으로 피해자의 목덜미를 수회 때리고, 계속하여 손으로 피해자의 머리를 눌러 자신의 허벅지 사이에 끼워 움직이지 못하게 한 다음, 주먹으로 등 부위를 수회 때렸다. 이로써 피고인 1은 인신구속에 관한 직무를 행함에 당하여 형사피의자인 피해자에게 폭행을 가하였다.',
#     'qas': [{'answers': [{'answer_start': 53.0, 'text': '피해자 공소외 23(31세)'}],
#       'id': '3316',
#       'question': '피해자가 누구인가요?'},
#      {'answers': [{'answer_start': 13.0, 'text': '2010. 3. 31. 11:50경'}],
#       'id': '3317',
#       'question': '범행이 언제 발생했나요?'},
#      {'answers': [{'answer_start': 137.0, 'text': '강력5팀 사무실에서'}],
#       'id': '3318',
#       'question': '범행이 어디서 발생했나요?'},
#      {'answers': [{'answer_start': 346.0, 'text': '폭행을 가하였다.'}],
#       'id': '3319',
#       'question': '범행이 어떻게 발생했나요?'}]}],
# ...

# %%
len(lawdict['data'])
# Out:
# 1004

# %% [markdown]
# # title의 paragraph 안에 여러 context (수정본)

# %%
lawdict = {}

dataList = []
datatmp = {}

paragraphList = []
paragraphtmp = {}

qasList = []
qastmp = {}

ansList = []
anstmp = {}

id = 0

allChar = set()
tmpStr = ""

questionList = ["제목","개수","범죄사실","피고인은 누구인가요?","피고인ansNum","피해자가 누구인가요?","피해자ansNum","범행이 언제 발생했나요?","범행ansNum","범행이 어디서 발생했나요?","장소ansNum","어떤 범행이 발생했나요?","범행ansNum"]

dataNum = 0

for row in range(1,nrow) :
        
    
    for col in range(3,ncol,2) : 
        if len(ws.cell_value(row,col)) > 0 :

            text = ws.cell_value(row,col)
            startNum = ws.cell_value(row,col+1)
            
            
            anstmp['answer_start'] = startNum
            anstmp['text'] = text
            ansList.append(anstmp)
            anstmp = {}
    
            qastmp['question'] = questionList[col]
            qastmp['answers'] = ansList
            qastmp['id'] = str(id) 
            
            qasList.append(qastmp)

            ansList = []
            qastmp = {}
            id = id+1
    
    paragraphtmp['context'] = ws.cell_value(row,2).strip()
    paragraphtmp['qas'] = qasList
    
    allChar.update([ a for a in paragraphtmp['context']])
    
    paragraphList.append(paragraphtmp)
    qasList = []
    paragraphtmp = {}
    
    
    
    if row == nrow - 1 or ( ws.cell_value(row,0) != ws.cell_value(row+1,0) ) :
    
        datatmp['title'] = ws.cell_value(row,0).strip()

        datatmp['paragraphs'] = paragraphList
    #     print(datatmp)
        dataList.append(copy.deepcopy(datatmp))
    #     dataList.append(datatmp)
        # copy.deepcopy 안해주면 모두 마지막 값이 들어가있다. 즉 datatmp 값이 모두 같아지는듯..
        # 근데 왜 여기서만 ??

        dattmp = {}
        paragraphList = []
        
        dataNum += 1

        
print("데이터 개수 :",dataNum)


random.shuffle(dataList)

lawdict['data'] = dataList
# Out:
# 데이터 개수 : 215

# %%
def replaceMultiple(mainString, toBeReplaces, newString):
    # Iterate over the strings to be replaced
    for elem in toBeReplaces :
        # Check if string is in the main string
        if elem in mainString :
            # Replace the string
            mainString = mainString.replace(elem, newString)
    
    return  mainString

allChar

specialChar = ['■', '□', '▲', '△', '▷', '▽', '▾', '◇', '◈', '○', '◎', '●', '◯', '☆', '☐', '☒', '☪', '☸', '☼', '☽', '♣','♤','♧']

lawStr = json.dumps(lawdict, ensure_ascii=False)

lawStr = replaceMultiple(lawStr, specialChar , "●")
# Out:
# 'qAAqAAqAA'

# %%
allChar

specialChar = ['■', '□', '▲', '△', '▷', '▽', '▾', '◇', '◈', '○', '◎', '●', '◯', '☆', '☐', '☒', '☪', '☸', '☼', '☽', '♣','♤','♧']

lawStr = json.dumps(lawdict, ensure_ascii=False)

lawStr = replaceMultiple(lawStr, specialChar , "●")

lawStr = replaceMultiple(lawStr, "󰏬" , "●●")

# %%
with open("./transformers/squadData/law500_multicontext_noun.json" , "w", encoding="utf-8") as make_file :
    make_file.write(lawStr)
# Out:
# {'data': [{'paragraphs': [{'context': '피고인은 중학교 체육교사로 2007. 3.경부터 2010. 3.경까지 ○○중학교의 육상부 감독으로 근무하면서 육상부원이었던 청소년 피해자 김○○(15세)를 지도하였고, 다른 학교로 전근한 이후에도 피해자를 만나 상담한 적이 있었다. 피고인은 2012. 3. 하순경 피해자에게 전화를 걸어 “오랜만에 만나 이야기를 하자.”고 말하여 2012. 3. 30. 17:00경 천안시 동남구 용곡동에 있는 용곡중학교 앞에서 피고인 소유의 38더****호 슈마 승용차에 피해자를 태우고 식사를 한 다음, 천안시 서북구 불당동 1367 태화관 식당 부근 도로가에 이르러 피고인의 승용차를 주차하고, 승용차 안에서 피해자와 대화를 하게 되었다. 피고인은 2012. 3. 30. 19:00경 위 피고인의 승용차에서, 피해자의 진로 문제 등에 관하여 대화를 하던 중 피해자와 단둘이 있게 되고, 그곳의 인적이 드물다는 점을 이용하여 피해자를 간음할 마음을 먹고 피해자의 입을 맞추고, 피해자에게 “안아보자.”고 말하여 피해자가 대답을 하지 않자, 피해자가 앉아 있는 조수석으로 가 몸으로 피해자의 몸과 양팔을 눌러 옷 속으로 피해자의 가슴을 만지고, 피해자의 속바지를 벗기며 간음하려 하였으나, 피해자가 피고인의 몸을 밀고 다리에 힘을 주며 반항하는 바람에 미수에 그쳤다. 피고인은 위와 같이 위력으로써 청소년인 피해자를 간음하려 하였으나 미수에 그쳤다.',
#      'qas': [{'answers': [{'answer_start': 5.0, 'text': '중학교 체육교사'}],
#        'id': '335',
#        'question': '피고인은 누구인가요?'},
#       {'answers': [{'answer_start': 61.0, 'text': '육상부원이었던 청소년 피해자 김○○(15세)'}],
#        'id': '336',
# ...

# %%
with open("./transformers/squadData/law500_multicontext_replace.json" , "w", encoding="utf-8") as make_file :
    json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")

# %% [markdown]
# # 하나의 질문만 있는 data set 여러개 생성 (수정본 )

# %%
questionList = ["제목","개수","범죄사실","피고인은 누구인가요?","피고인ansNum","피해자가 누구인가요?","피해자ansNum","범행이 언제 발생했나요?","범행ansNum","범행이 어디서 발생했나요?","장소ansNum","어떤 범행이 발생했나요?","범행ansNum"]

TitleToNum = {}
TitleToNum['defendant'] = 3
TitleToNum['victim'] = 5
TitleToNum['when'] = 7
TitleToNum['where'] = 9 
TitleToNum['what'] = 11


for question in ['defendant' , 'victim', 'when', 'where', 'what'] : 

    notData = [ TitleToNum['defendant'], TitleToNum['victim'], TitleToNum['when'], TitleToNum['where'], TitleToNum['what'] ]

    notData = [item for item in notData if item not in [TitleToNum[question]]]
    
    print(notData)
    
    lawdict = {}

    dataList = []
    datatmp = {}

    paragraphList = []
    paragraphtmp = {}

    qasList = []
    qastmp = {}

    ansList = []
    anstmp = {}

    id = 0
    
    dataNum = 0

    for row in range(1,nrow) :

        for col in range(3,ncol,2) : 

            if col not in notData : 

                if len(ws.cell_value(row,col)) > 0 :

                    text = ws.cell_value(row,col)
                    startNum = ws.cell_value(row,col+1)


                    anstmp['answer_start'] = startNum
                    anstmp['text'] = text
                    ansList.append(anstmp)
                    anstmp = {}


                    qastmp['question'] = questionList[col]
                    qastmp['answers'] = ansList
                    qastmp['id'] = str(id) 

                    qasList.append(qastmp)

                    ansList = []
                    qastmp = {}
                    id = id+1

        paragraphtmp['context'] = ws.cell_value(row,2).strip()
        paragraphtmp['qas'] = qasList

        paragraphList.append(paragraphtmp)
        qasList = []
        paragraphtmp = {}




        datatmp['title'] = ws.cell_value(row,0).strip()

        datatmp['paragraphs'] = paragraphList
        #     print(datatmp)
        dataList.append(copy.deepcopy(datatmp))
        #     dataList.append(datatmp)
            # copy.deepcopy 안해주면 모두 마지막 값이 들어가있다. 즉 datatmp 값이 모두 같아지는듯..
            # 근데 왜 여기서만 ??

        dattmp = {}
        paragraphList = []

        dataNum += 1



            

    print("데이터 개수 :",dataNum)
    
    random.shuffle(dataList)
    
    lawdict['data'] = dataList
    
    with open("./transformers/squadData/law1004_"+ question +".json" , "w", encoding="utf-8") as make_file :
        json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")
# Out:
# [5, 7, 9, 11]
# 데이터 개수 : 1001
# [3, 7, 9, 11]
# 데이터 개수 : 1001
# [3, 5, 9, 11]
# 데이터 개수 : 1001
# [3, 5, 7, 11]
# 데이터 개수 : 1001
# [3, 5, 7, 9]
# 데이터 개수 : 1001

# %%
with open("./data/final_onlyWhere_v1.json" , "w", encoding="utf-8") as make_file :
    json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")

# %% [markdown]
# # 3. train-test split

# %%
with open('./transformers/squadData/law1001_toy.json') as json_file:
    json_data = json.load(json_file)

print(json_data.keys(),"\n")
print("data 안에 :",json_data['data'][0].keys(),"\n")
print("Title :",json_data['data'][0]['title'],"\n")
print("paragraphs 안에 :",json_data['data'][0]['paragraphs'][0].keys(),"\n")
print("Context :",json_data['data'][0]['paragraphs'][0]['context'],"\n")
print("qas 안에 :",json_data['data'][0]['paragraphs'][0]['qas'][0].keys(),"\n")
print("qas :",json_data['data'][0]['paragraphs'][0]['qas'][0])
# Out:
# dict_keys(['data'])
#
# data 안에 : dict_keys(['title', 'paragraphs'])
#
# Title : 창원지방법원 2018. 10. 22. 선고 2018고합118, 2018전고12(병합) 판결 【성폭력범죄의처벌등에관한특례법위반(장애인강제추행) 등】
#
# paragraphs 안에 : dict_keys(['context', 'qas'])
#
# Context : 피고인은 2018. 3. 21. 16:35경 김해시 대청동 D빌딩 1층 복도에서 담배를 피우던 중 위 빌딩 2층에 있는 장애인자립재활센터에서 일을 마친 후 귀가 차량을 기다리던 피해자 F(여, 25세, 지적장애 1급)을 발견하고 피해자를 강제추행하기로 마음먹고 피해자에게 다가가 “아유 예쁘네.”라고 말하면서 손으로 갑자기 피해자의 얼굴을 쓰다듬고, 주변의 시선을 피하기 위해서 입고 있던 점퍼로 피해자의 몸을 가린 후 손으로 피해자의 가슴을 주무르고, 또다시 피해자의 얼굴을 손으로 쓰다듬고 피해자의 허리를 팔로 감싸 안은 후에 피해자의 입술에 자신의 입술을 맞추고, 이에 놀란 피해자가 “하지마.”라고 소리치며 달아나자 피해자를 뒤따라가 재차 피고인을 밀치며 거부하는 피해자의 가슴을 만졌다. 이로써 피고인은 정신적인 장애 및 신체적인 장애1)가 있는 사람을 강제추행하였다.
#
# qas 안에 : dict_keys(['question', 'answers', 'id'])
#
# qas : {'question': '피해자가 누구인가요?', 'answers': [{'answer_start': 99.0, 'text': '피해자 F(여, 25세, 지적장애 1급)'}], 'id': '8'}

# %%
length = len(json_data['data'])
train_length = int(length * 0.7)

print("총 데이터 개수 :",length)

train = {}
test = {}

trainList = []
testList = []

for i in range(train_length):
    trainList.append(json_data['data'][i])
    
for i in range(train_length,length) :
    testList.append(json_data['data'][i])

print("> Train :",len(trainList),"Test :",len(testList))

train['data'] = trainList
test['data'] = testList
# Out:
# 총 데이터 개수 : 19
# > Train : 13 Test : 6

# %%
with open("./transformers/squadData/train1001_toy.json" , "w", encoding="utf-8") as make_file :
    json.dump(train, make_file, ensure_ascii=False, indent="\t")
    
with open("./transformers/squadData/test1001_toy.json" , "w", encoding="utf-8") as make_file :
    json.dump(test, make_file, ensure_ascii=False, indent="\t")

# %%
for ques in ['victim', 'when', 'where', 'what'] : 

    with open('./transformers/squadData/law1004_'+ques+'.json') as json_file:
        json_data = json.load(json_file)


    length = len(json_data['data'])
    train_length = int(length * 0.7)

    print("총 데이터 개수 :",length)

    train = {}
    test = {}

    trainList = []
    testList = []

    for i in range(train_length):
        trainList.append(json_data['data'][i])

    for i in range(train_length,length) :
        testList.append(json_data['data'][i])

    print("> Train :",len(trainList),"Test :",len(testList))

    train['data'] = trainList
    test['data'] = testList


    with open("./transformers/squadData/train1004_"+ques+".json" , "w", encoding="utf-8") as make_file :
        json.dump(train, make_file, ensure_ascii=False, indent="\t")

    with open("./transformers/squadData/test1004_"+ques+".json" , "w", encoding="utf-8") as make_file :
        json.dump(test, make_file, ensure_ascii=False, indent="\t")
# Out:
# 총 데이터 개수 : 1001
# > Train : 700 Test : 301
# 총 데이터 개수 : 1001
# > Train : 700 Test : 301
# 총 데이터 개수 : 1001
# > Train : 700 Test : 301
# 총 데이터 개수 : 1001
# > Train : 700 Test : 301

# %%
wb=xlrd.open_workbook("./data/law1004.xlsx")
# wb=xlrd.open_workbook("./data/law_raw_data_oneanswer.xlsx")

ws=wb.sheet_by_index(0)

nrow = ws.nrows
ncol = ws.ncols
print("row개수 :",nrow)
print("col개수 :",ncol) 

lawdict = {}

dataList = []
datatmp = {}

paragraphList = []
paragraphtmp = {}

qasList = []
qastmp = {}

ansList = []
anstmp = {}

id = 0

questionList = ["제목","개수","범죄사실","피고인은 누구인가요?","피고인ansNum","피해자가 누구인가요?","피해자ansNum","범행이 언제 발생했나요?","범행ansNum","범행이 어디서 발생했나요?","장소ansNum","어떤 범행이 발생했나요?","범행ansNum"]

dataNum = 0

for row in range(1,nrow) :
        
    
    for col in range(3,ncol,2) : 
        if len(ws.cell_value(row,col)) > 0 :

            text = ws.cell_value(row,col)
            startNum = ws.cell_value(row,col+1)
            
            
            anstmp['answer_start'] = startNum
            anstmp['text'] = text
            ansList.append(anstmp)
            anstmp = {}
    
    
            qastmp['question'] = questionList[col]
            qastmp['answers'] = ansList
            qastmp['id'] = str(id) 
            
            qasList.append(qastmp)

            ansList = []
            qastmp = {}
            id = id+1
    
    paragraphtmp['context'] = ws.cell_value(row,2).strip()
    paragraphtmp['qas'] = qasList
    
    paragraphList.append(paragraphtmp)
    qasList = []
    paragraphtmp = {}
    
    
    datatmp['title'] = ws.cell_value(row,0).strip()
    
    datatmp['paragraphs'] = paragraphList
#     print(datatmp)
    dataList.append(copy.deepcopy(datatmp))
#     dataList.append(datatmp)
    # copy.deepcopy 안해주면 모두 마지막 값이 들어가있다. 즉 datatmp 값이 모두 같아지는듯..
    # 근데 왜 여기서만 ??
    
    dattmp = {}
    paragraphList = []
    
    dataNum += 1

        
print("데이터 개수 :",dataNum)

random.shuffle(dataList)

lawdict['data'] = dataList

with open("./EtriBERT/squadData/law1004.json" , "w", encoding="utf-8") as make_file :
    json.dump(lawdict, make_file, ensure_ascii=False, indent="\t")
# Out:
# row개수 : 999
# col개수 : 13
# 데이터 개수 : 998

# %%
with open('./transformers/squadData/law1004.json') as json_file:
    json_data = json.load(json_file)

# %%
true_dict = {}

for paragraphs_title in json_data['data'] :
    for pq in paragraphs_title['paragraphs'] :
        for qa in pq['qas'] :
            qas_id = qa['id']
            qas_ans = qa['answers'][0]['text']
            true_dict[qas_id] = qas_ans
len(true_dict)
# Out:
# 4075

# %%
wb=xlrd.open_workbook("./data/law1001_toy.xlsx")
# wb=xlrd.open_workbook("./data/law_raw_data_oneanswer.xlsx")

ws=wb.sheet_by_index(0)

ws

nrow = ws.nrows
ncol = ws.ncols
print("row개수 :",nrow)
print("col개수 :",ncol)
# Out:
# row개수 : 20
# col개수 : 13

# %%
lawdict = {}

dataList = []
datatmp = {}

paragraphList = []
paragraphtmp = {}

qasList = []
qastmp = {}

ansList = []
anstmp = {}

id = 0

qNum = {"5":0,"7":0,"9":0,"11":0}

questionList = ["제목","개수","범죄사실","피고인은 누구인가요?","피고인ansNum","피해자가 누구인가요?","피해자ansNum","범행이 언제 발생했나요?","범행ansNum","범행이 어디서 발생했나요?","장소ansNum","어떤 범행이 발생했나요?","범행ansNum"]

tag = {6:"HO",10:"RE",8:"EN",12:"AT"}

dataNum = 0
namedEntity = {}

Ilist = list(range(1,nrow))
random.shuffle(Ilist)
print(Ilist)
maxLen = []
with open("./transformers/NER/tae/data/train_toy.txt","w") as f :
        
    for row in Ilist[:-300] :


        criminalFact = ws.cell_value(row,2)
        maxLen.append(len(criminalFact))
        NERIDict = {}
        NERBDict= {}
        for num in [6,8,10,12] :
            BnumList = [int(ws.cell_value(row,num))]
            BtagList = [tag[num]] 
            InumList = list(range(int(ws.cell_value(row,num))+1 , int(ws.cell_value(row,num)) + len(ws.cell_value(row,num-1))))
            ItagList = [tag[num]] * (len(ws.cell_value(row,num-1))-1)
            NERIDict.update(dict(zip(InumList,ItagList)))
            NERBDict.update(dict(zip(BnumList,BtagList)))
            
#         print(NERDict)


        for i in range(len(criminalFact)) :
            if i in NERIDict.keys() :
#                 print(criminalFact[i] +"\t"+ NERDict[i])
                f.write(criminalFact[i] +" I-"+ NERIDict[i]+"\n")

            elif i in NERBDict.keys() :
                f.write(criminalFact[i] +" B-"+ NERBDict[i]+"\n")
                

            else :
#                 print(criminalFact[i]+"\tO")
                f.write(criminalFact[i]+" O\n")
        dataNum += 1
        
#         print("")
        f.write("\n")
        
print("train 데이터 개수 :",dataNum)



dataNum = 0
namedEntity = {}

with open("./transformers/NER/tae/data/test_toy.txt","w") as f :
        
    for row in Ilist[-300:] :


        criminalFact = ws.cell_value(row,2)
        maxLen.append(len(criminalFact))
        NERIDict = {}
        NERBDict = {}
        
        for num in [6,8,10,12] :
            BnumList = [int(ws.cell_value(row,num))]
            BtagList = [tag[num]]
            InumList = list(range(int(ws.cell_value(row,num))+1 , int(ws.cell_value(row,num)) + len(ws.cell_value(row,num-1))))
            ItagList = [tag[num]] * (len(ws.cell_value(row,num-1))-1)
            NERIDict.update(dict(zip(InumList,ItagList)))
            NERBDict.update(dict(zip(BnumList,BtagList)))
            
#         print(NERDict)
        print(NERBDict.keys())
    
        for i in range(len(criminalFact)) :
            if i in NERIDict.keys() :
#                 print(criminalFact[i] +"\t"+ NERDict[i])
                f.write(criminalFact[i] +" I-"+ NERIDict[i]+"\n")
            
            
            elif i in NERBDict.keys() :
                f.write(criminalFact[i] +" B-"+ NERBDict[i]+"\n")
            
            else :
#                 print(criminalFact[i]+"\tO")
                f.write(criminalFact[i]+" O\n")
        dataNum += 1
        
#         print("")
        f.write("\n")
        
print("test 데이터 개수 :",dataNum)
# Out:
# [1, 4, 9, 5, 17, 11, 16, 14, 8, 7, 13, 6, 2, 15, 10, 3, 19, 18, 12]
# train 데이터 개수 : 9
# dict_keys([104, 289, 266, 550])
# dict_keys([81, 5, 140, 332])
# dict_keys([201, 144, 181, 338])
# dict_keys([195, 165, 210, 512])
# dict_keys([97, 5, 50, 145])
# dict_keys([68, 5, 60, 194])
# dict_keys([99, 5, 67, 429])
# dict_keys([86, 5, 44, 174])
# dict_keys([67, 5, 48, 131])
# dict_keys([178, 283, 323, 534])
# test 데이터 개수 : 10

# %%
sorted(maxLen)
# Out:
# [69,
#  72,
#  73,
#  77,
#  83,
#  87,
#  89,
#  91,
#  93,
#  93,
#  95,
#  95,
#  96,
#  96,
#  96,
#  99,
#  100,
#  101,
#  101,
#  102,
#  103,
#  106,
#  106,
#  106,
#  106,
#  106,
#  107,
#  107,
#  107,
#  107,
#  107,
#  108,
#  108,
#  108,
#  109,
#  110,
#  110,
#  111,
#  111,
#  111,
#  111,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  113,
#  114,
#  114,
#  114,
#  115,
#  115,
#  115,
#  115,
#  115,
#  115,
#  116,
#  116,
#  116,
#  116,
#  118,
#  118,
#  119,
#  119,
#  120,
#  120,
#  121,
#  124,
#  124,
#  125,
#  125,
#  126,
#  126,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  127,
#  128,
#  128,
#  128,
#  129,
#  129,
#  131,
#  131,
#  131,
#  131,
#  131,
#  132,
#  132,
#  133,
#  133,
#  133,
#  133,
#  133,
#  134,
#  134,
#  135,
#  135,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  137,
#  138,
#  138,
#  138,
#  139,
#  139,
#  139,
#  139,
#  140,
#  140,
#  140,
#  140,
#  140,
#  141,
#  141,
#  141,
#  142,
#  142,
#  142,
# ...

# %%
with open("/home/junho/AIlaw/transformers/NER/tae/data/test.txt" , "r") as f:
    line = f.readlines()
    print(line)
    print("Z")
# Out:
# ['1951 O\n', 'bis O\n', '1953 O\n', 'wurde O\n', 'der O\n', 'nördliche O\n', 'Teil O\n', 'als O\n', 'Jugendburg O\n', 'des O\n', 'Kolpingwerkes B-OTH\n', 'gebaut O\n', '. O\n', '\n', 'Da O\n', 'Muck B-PER\n', 'das O\n', 'Kriegsschreiben O\n', 'nicht O\n', 'überbracht O\n', 'hat O\n', ', O\n', 'wird O\n', 'er O\n', 'als O\n', 'Retter O\n', 'des O\n', 'Landes O\n', 'ausgezeichnet O\n', 'und O\n', 'soll O\n', 'zum O\n', 'Schatzmeister O\n', 'ernannt O\n', 'werden O\n', '. O\n', '\n', 'Mit O\n', '1. O\n', 'Jänner O\n', '2007 O\n', 'wurde O\n', 'Robert B-PER\n', 'Schörgenhofer I-PER\n', ', O\n', 'als O\n', 'Nachfolger O\n', 'des O\n', 'ausgeschiedenen O\n', 'Dietmar B-PER\n', 'Drabek I-PER\n', ', O\n', 'in O\n', 'die O\n', 'Kaderliste O\n', 'der O\n', 'FIFA-Schiedsrichter B-ORGpart\n', 'aufgenommen O\n', '. O\n', '\n', 'Die O\n', 'These O\n', ', O\n', 'Schlatter B-PER\n', 'sei O\n', 'Antisemit O\n', 'gewesen O\n', ', O\n', 'wurde O\n', 'seither O\n', 'in O\n', 'der O\n', 'theologischen O\
# ...

# %%
num = 0
for l in line :
    if len(l.split()) >= 1 :
        st = l.split()[0]
#         print(len(st) , st)
        num += len(st)
    else :
        print(num)
        num = 0
# Out:
# 68
# 117
# 134
# 100
# 151
# 82
# 43
# 51
# 102
# 167
# 79
# 81
# 70
# 62
# 73
# 84
# 50
# 214
# 117
# 157
# 150
# 190
# 22
# 48
# 146
# 111
# 65
# 63
# 60
# 87
# 157
# 141
# 148
# 49
# 57
# 46
# 70
# 86
# 62
# 115
# 87
# 43
# 106
# 84
# 179
# 88
# 104
# 110
# 81
# 163
# 165
# 85
# 111
# 50
# 112
# 131
# 69
# 102
# 74
# 128
# 102
# 144
# 113
# 169
# 46
# 69
# 47
# 174
# 92
# 154
# 59
# 180
# 121
# 33
# 96
# 114
# 161
# 89
# 84
# 89
# 170
# 198
# 54
# 145
# 53
# 89
# 164
# 167
# 160
# 133
# 83
# 82
# 76
# 111
# 102
# 45
# 215
# 81
# 165
# 101
# 38
# 141
# 168
# 97
# 211
# 71
# 82
# 146
# 99
# 75
# 34
# 154
# 44
# 199
# 92
# 106
# 63
# 83
# 173
# 180
# 63
# 71
# 124
# 173
# 120
# 47
# 95
# 81
# 101
# 48
# 62
# 34
# 193
# 48
# 93
# 72
# 168
# 56
# 54
# 72
# 69
# 125
# 80
# 128
# 57
# 41
# 38
# 154
# 77
# 168
# 190
# 78
# 63
# 51
# 98
# 46
# 169
# 63
# 89
# 90
# 48
# 144
# 136
# 73
# 66
# 150
# 162
# 30
# 104
# 69
# 67
# 60
# 129
# 110
# 49
# 61
# 187
# 70
# 46
# 61
# 30
# 117
# 188
# ...
